# %%
import numpy as np
import datetime

# %%
dict_slot = {"d4p1:AppointmentSlot": [
  {
    "d4p1:AppointmentDate": "2017-11-20T08:30:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T08:40:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T08:50:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T09:10:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T09:20:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T09:30:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T09:40:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T09:50:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T10:00:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T10:10:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T10:20:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T10:30:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T10:40:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T10:50:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T11:00:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T11:10:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T11:20:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T11:30:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T11:40:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T11:50:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T12:00:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T12:10:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T12:20:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T13:30:00",
    "d4p1:Id": "0"
  },
  {
    "d4p1:AppointmentDate": "2017-11-20T13:40:00",
    "d4p1:Id": "0"
  },
    {
    "d4p1:AppointmentDate": "2018-01-08T08:30:00",
    "d4p1:Id": "0"
  }
]
  
,"preferred_datetimes": [
    {
      "start_date": "2018-01-08",
      "end_date": "2018-01-13",
      "preferred_times": [
        {
          "start_time": "08:00",
          "end_time": "12:00"
        },
        {
          "start_time": "16:00",
          "end_time": "19:30"
        }
      ],
      "time_exceptions": [
        {
          "start_time": "09:45",
          "end_time": "10:15"
        }
      ]
    },
    {
      "start_date": "2018-02-03",
      "end_date": "2018-02-12",
      "preferred_times": [
        {
          "start_time": "16:00",
          "end_time": "19:00"
        }
      ],
      "time_exceptions": [
        
      ]
    }
  ],
  "weekdays": [
    "1",
    "2",
    "3",
    "5"
  ],
  "date_exceptions": [
    {
      "start_date": "2018-01-09",
      "end_date": "2018-01-09"
    },
    {
      "start_date": "2018-02-05",
      "end_date": "2018-02-06"
    }
  ]
            }

# %%
# setting id
for i in range(len(app)):
    app[i]["d4p1:Id"] = i
    pass
app = dict_slot["d4p1:AppointmentSlot"]
pre = dict_slot["preferred_datetimes"]

# %%
def appointment_scheduler(app,pre,i):
    start_date = pre[i]['start_date']
    end_date = pre[i]['end_date']
    time = pre[i]['preferred_times']
    date_list = []
    for i in range(len(app)):
        date = app[i]
        app_date = date['d4p1:AppointmentDate']
        app_id = date['d4p1:Id']
        app_date = app_date.split("T")
        if(app_date[0] >= start_date and app_date[0] <= end_date):
            for j in range(len(time)):
                start_time = time[j]["start_time"]
                if(app_date[1] >= start_time):
                    s = datetime.datetime.strptime(app_date[0], "%Y-%m-%d")
                    s = s.strftime('%B %d %Y')
                    hour = app_date.split(":")
                    hour_slot = []
                    dict1 = {app_date[1] : app_id}
                    hour_slot.append(dict1)
                    hour_dict = {"hour":hour[0],"hour_slots":hour_slot}
                    date_slot = []
                    date_slot.append(hour_dict)
                    out = {"date" : s,"date_slots": date_slot}
                    output["available_slots"].append(out)
                    app.pop(i)

# %%
for i in range(len(pre)):
    appointment_scheduler(app,pre,i)
    
print(output)
# Out:
# {'available_slots': [{'date': 'January 08 2018', 'date_slots': '2018-01-08'}, {'date': 'January 08 2018', 'date_slots': '2018-01-08'}]}
